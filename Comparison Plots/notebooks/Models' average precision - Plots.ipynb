# %% [markdown]
# # <div align="center"><u>Models' average precision - Plots</u></div>
#
# ## General description of the "Models' average precision - Plots" file
#
# The following analysis includes just plots (for every model):
#
# ### 1. Metrics Overview:
#
# **Evaluation metrics:**
# - Average evaluation precision
# - Average evaluation precision's standard deviation

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ###  Import some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Suppress warnings

# %%
# import warnings

# # To suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # <div align="center"><u> 1. Metrics overview </u>

# %% [markdown]
# ## <div align="center"><u> Evaluation metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average evaluation precision </u>

# %% [markdown]
# ### Store the average evaluation precision

# %%
# Store the average evaluation precision
averageEvaluationPrecision = {
    "MLP - No DR": 0.9752,
    "MLP - Low Variance": 0.9752,
    "MLP - High Pearson Correlation": 0.9071,
    "MLP - High Spearman's Rank Correlation": 0.8445,
    "MLP - Low Mutual Info Dependency": 0.9811,
    "MLP - NNG-GS": 0.9688,
    "MLP - MDG-GS": 0.9676,
    "MLP - CDG-GS": 0.9432,
    "kNN - No DR": 0.9799,
    "kNN - Low Variance": 0.9696,
    "kNN - High Pearson Correlation": 0.8637,
    "kNN - High Spearman's Rank Correlation": 0.8021,
    "kNN - Low Mutual Info Dependency": 0.9811,
    "kNN - NNG-GS": 0.9568,
    "kNN - MDG-GS": 0.9627,
    "kNN - CDG-GS": 0.8764,
    "AdaBoost - No DR": 0.9754,
    "AdaBoost - Low Variance": 0.9771,
    "AdaBoost - High Pearson Correlation": 0.8883,
    "AdaBoost - High Spearman's Rank Correlation": 0.8560,
    "AdaBoost - Low Mutual Info Dependency": 0.9763,
    "AdaBoost - NNG-GS": 0.9720,
    "AdaBoost - MDG-GS": 0.9709,
    "AdaBoost - CDG-GS": 0.8935,
    "Naive Bayes - No DR": 0.9712,
    "Naive Bayes - Low Variance": 0.9766,
    "Naive Bayes - High Pearson Correlation": 0.8968,
    "Naive Bayes - High Spearman's Rank Correlation": 0.8608,
    "Naive Bayes - Low Mutual Info Dependency": 0.9784,
    "Naive Bayes - NNG-GS": 0.9722,
    "Naive Bayes - MDG-GS": 0.9686,
    "Naive Bayes - CDG-GS": 0.7607,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationPrecisionNames = list(averageEvaluationPrecision.keys())
averageEvaluationPrecisionValues = list(averageEvaluationPrecision.values())

# %% [markdown]
# ### Plot average evaluation precision

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationPrecisionNames, averageEvaluationPrecisionValues, color='yellow', width=0.2)
plt.ylabel("Average evaluation precision", fontsize = 12)
plt.title("Models' average evaluation precision", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation precision in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationPrecision = dict(sorted(averageEvaluationPrecision.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationPrecisionNames = list(sorted_averageEvaluationPrecision.keys())
sorted_averageEvaluationPrecisionValues = list(sorted_averageEvaluationPrecision.values())

# %% [markdown]
# ### Plot sorted average evaluation precision

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationPrecisionNames, sorted_averageEvaluationPrecisionValues, color='yellow', width=0.2)
plt.ylabel("Average evaluation precision", fontsize = 12)
plt.title("Models' average evaluation precision - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average evaluation precision's standard deviation </u>

# %% [markdown]
# ### Store the average evaluation precision's standard deviation

# %%
# Store the average evaluation precision's standard deviation
averageEvaluationPrecisionStd = {
    "MLP - No DR": 0.0117,
    "MLP - Low Variance": 0.0115,
    "MLP - High Pearson Correlation": 0.0232,
    "MLP - High Spearman's Rank Correlation": 0.0307,
    "MLP - Low Mutual Info Dependency": 0.0106,
    "MLP - NNG-GS": 0.0137,
    "MLP - MDG-GS": 0.0124,
    "MLP - CDG-GS": 0.0166,
    "kNN - No DR": 0.0108,
    "kNN - Low Variance": 0.0120,
    "kNN - High Pearson Correlation": 0.0212,
    "kNN - High Spearman's Rank Correlation": 0.0276,
    "kNN - Low Mutual Info Dependency": 0.0116,
    "kNN - NNG-GS": 0.0143,
    "kNN - MDG-GS": 0.0144,
    "kNN - CDG-GS": 0.0294,
    "AdaBoost - No DR": 0.0142,
    "AdaBoost - Low Variance": 0.0109,
    "AdaBoost - High Pearson Correlation": 0.0257,
    "AdaBoost - High Spearman's Rank Correlation": 0.0303,
    "AdaBoost - Low Mutual Info Dependency": 0.0119,
    "AdaBoost - NNG-GS": 0.0120,
    "AdaBoost - MDG-GS": 0.0145,
    "AdaBoost - CDG-GS": 0.0256,
    "Naive Bayes - No DR": 0.0146,
    "Naive Bayes - Low Variance": 0.0114,
    "Naive Bayes - High Pearson Correlation": 0.0253,
    "Naive Bayes - High Spearman's Rank Correlation": 0.0272,
    "Naive Bayes - Low Mutual Info Dependency": 0.0124,
    "Naive Bayes - NNG-GS": 0.0122,
    "Naive Bayes - MDG-GS": 0.0128,
    "Naive Bayes - CDG-GS": 0.0461,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationPrecisionStdNames = list(averageEvaluationPrecisionStd.keys())
averageEvaluationPrecisionStdValues = list(averageEvaluationPrecisionStd.values())

# %% [markdown]
# ### Plot average evaluation precision's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationPrecisionStdNames, averageEvaluationPrecisionStdValues, color='darksalmon', width=0.2)
plt.ylabel("Average evaluation precision's standard deviation", fontsize = 12)
plt.title("Models' average evaluation precision's standard deviation", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation precision's standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationPrecisionStd = dict(sorted(averageEvaluationPrecisionStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationPrecisionStdNames = list(sorted_averageEvaluationPrecisionStd.keys())
sorted_averageEvaluationPrecisionStdValues = list(sorted_averageEvaluationPrecisionStd.values())

# %% [markdown]
# ### Plot sorted average evaluation precision's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationPrecisionStdNames, sorted_averageEvaluationPrecisionStdValues, color='darksalmon', width=0.2)
plt.ylabel("Average evaluation precision's standard deviation", fontsize = 12)
plt.title("Models' average evaluation precision's standard deviation - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()
