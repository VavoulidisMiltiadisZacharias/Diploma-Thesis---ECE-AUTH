# %% [markdown]
# # <div align="center"><u>Models' average confussion matrices - Plots</u></div>
#
# ## General description of the "Models' average confussion matrices - Plots" file
#
# The following analysis includes just plots (for every model), regarding the average confusion matrix in each case:
#
# ### 1. Metrics Overview:
#
# **Evaluation metrics:**
# - Average True Positives
# - Average True Negatives
# - Average False Positives
# - Average False Negatives

# %%
##############################################################################################################################

# %% [markdown]
# ###  Import some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Suppress warnings

# %%
# import warnings

# # To suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # <div align="center"><u> 1. Metrics overview </u>

# %% [markdown]
# ## <div align="center"><u> Evaluation metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average True Positives </u>

# %% [markdown]
# ### Store the average True Positives

# %%
# Store the average True Positives
averageTruePositives = {
    "MLP - No DR": 70.63,
    "MLP - Low Variance": 70.26,
    "MLP - High Pearson Correlation": 64.74,
    "MLP - High Spearman's Rank Correlation": 60.66,
    "MLP - Low Mutual Info Dependency": 70.64,
    "MLP - NNG-GS": 70.00,
    "MLP - MDG-GS": 70.20,
    "MLP - CDG-GS": 68.96,
    "kNN - No DR": 71.18,
    "kNN - Low Variance": 70.64,
    "kNN - High Pearson Correlation": 57.28,
    "kNN - High Spearman's Rank Correlation": 57.08,
    "kNN - Low Mutual Info Dependency": 70.48,
    "kNN - NNG-GS": 69.70,
    "kNN - MDG-GS": 68.50,
    "kNN - CDG-GS": 65.66,
    "AdaBoost - No DR": 70.20,
    "AdaBoost - Low Variance": 70.30,
    "AdaBoost - High Pearson Correlation": 63.56,
    "AdaBoost - High Spearman's Rank Correlation": 61.92,
    "AdaBoost - Low Mutual Info Dependency": 70.28,
    "AdaBoost - NNG-GS": 69.92,
    "AdaBoost - MDG-GS": 69.68,
    "AdaBoost - CDG-GS": 65.96,
    "Naive Bayes - No DR": 69.44,
    "Naive Bayes - Low Variance": 70.42,
    "Naive Bayes - High Pearson Correlation": 63.04,
    "Naive Bayes - High Spearman's Rank Correlation": 61.82,
    "Naive Bayes - Low Mutual Info Dependency": 70.16,
    "Naive Bayes - NNG-GS": 70.02,
    "Naive Bayes - MDG-GS": 70.04,
    "Naive Bayes - CDG-GS": 48.72,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageTruePositivesNames = list(averageTruePositives.keys())
averageTruePositivesValues = list(averageTruePositives.values())

# %% [markdown]
# ### Plot average True Positives

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageTruePositivesNames, averageTruePositivesValues, color='green', width=0.2)
plt.ylabel("Average True Positives", fontsize = 12)
plt.title("Models' average True Positives (confusion matrix)", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 85)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1.2, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average True Positives in ascending order

# %%
# Sort by values (ascending)
sorted_averageTruePositives = dict(sorted(averageTruePositives.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageTruePositivesNames = list(sorted_averageTruePositives.keys())
sorted_averageTruePositivesValues = list(sorted_averageTruePositives.values())

# %% [markdown]
# ### Plot sorted average True Positives

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageTruePositivesNames, sorted_averageTruePositivesValues, color='green', width=0.2)
plt.ylabel("Average True Positives", fontsize = 12)
plt.title("Models' average True Positives (confusion matrix) - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 85)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1.2, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <div align="center"><u> Average True Negatives </u>

# %% [markdown]
# ### Store the average True Positives

# %%
# Store the average True Negatives
averageTrueNegatives = {
    "MLP - No DR": 63.18,
    "MLP - Low Variance": 63.28,
    "MLP - High Pearson Correlation": 59.36,
    "MLP - High Spearman's Rank Correlation": 54.42,
    "MLP - Low Mutual Info Dependency": 63.74,
    "MLP - NNG-GS": 62.66,
    "MLP - MDG-GS": 62.30,
    "MLP - CDG-GS": 60.08,
    "kNN - No DR": 63.02,
    "kNN - Low Variance": 62.12,
    "kNN - High Pearson Correlation": 59.76,
    "kNN - High Spearman's Rank Correlation": 52.48,
    "kNN - Low Mutual Info Dependency": 63.90,
    "kNN - NNG-GS": 61.30,
    "kNN - MDG-GS": 62.28,
    "kNN - CDG-GS": 54.08,
    "AdaBoost - No DR": 63.40,
    "AdaBoost - Low Variance": 63.52,
    "AdaBoost - High Pearson Correlation": 57.92,
    "AdaBoost - High Spearman's Rank Correlation": 55.16,
    "AdaBoost - Low Mutual Info Dependency": 63.42,
    "AdaBoost - NNG-GS": 63.18,
    "AdaBoost - MDG-GS": 63.26,
    "AdaBoost - CDG-GS": 56.22,
    "Naive Bayes - No DR": 63.54,
    "Naive Bayes - Low Variance": 63.32,
    "Naive Bayes - High Pearson Correlation": 59.94,
    "Naive Bayes - High Spearman's Rank Correlation": 55.92,
    "Naive Bayes - Low Mutual Info Dependency": 63.84,
    "Naive Bayes - NNG-GS": 63.12,
    "Naive Bayes - MDG-GS": 62.60,
    "Naive Bayes - CDG-GS": 53.86,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageTrueNegativesNames = list(averageTrueNegatives.keys())
averageTrueNegativesValues = list(averageTrueNegatives.values())

# %% [markdown]
# ### Plot average True Negatives

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageTrueNegativesNames, averageTrueNegativesValues, color='red', width=0.2)
plt.ylabel("Average True Negatives", fontsize = 12)
plt.title("Models' average True Negatives (confusion matrix)", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 85)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1.2, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average True Negatives in ascending order

# %%
# Sort by values (ascending)
sorted_averageTrueNegatives = dict(sorted(averageTrueNegatives.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageTrueNegativesNames = list(sorted_averageTrueNegatives.keys())
sorted_averageTrueNegativesValues = list(sorted_averageTrueNegatives.values())

# %% [markdown]
# ### Plot sorted average True Negatives

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageTrueNegativesNames, sorted_averageTrueNegativesValues, color='red', width=0.2)
plt.ylabel("Average True Negatives", fontsize = 12)
plt.title("Models' average True Negatives (confusion matrix) - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 85)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1.2, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <div align="center"><u> Average False Positives </u>

# %%
# Store the average False Positives
averageFalsePositives = {
    "MLP - No DR": 1.82,
    "MLP - Low Variance": 1.72,
    "MLP - High Pearson Correlation": 5.46,
    "MLP - High Spearman's Rank Correlation": 10.18,
    "MLP - Low Mutual Info Dependency": 1.26,
    "MLP - NNG-GS": 2.34,
    "MLP - MDG-GS": 2.70,
    "MLP - CDG-GS": 4.92,
    "kNN - No DR": 1.98,
    "kNN - Low Variance": 2.88,
    "kNN - High Pearson Correlation": 5.24,
    "kNN - High Spearman's Rank Correlation": 12.52,
    "kNN - Low Mutual Info Dependency": 1.10,
    "kNN - NNG-GS": 3.70,
    "kNN - MDG-GS": 1.72,
    "kNN - CDG-GS": 10.92,
    "AdaBoost - No DR": 1.60,
    "AdaBoost - Low Variance": 1.48,
    "AdaBoost - High Pearson Correlation": 7.08,
    "AdaBoost - High Spearman's Rank Correlation": 9.84,
    "AdaBoost - Low Mutual Info Dependency": 1.58,
    "AdaBoost - NNG-GS": 1.82,
    "AdaBoost - MDG-GS": 1.74,
    "AdaBoost - CDG-GS": 8.78,
    "Naive Bayes - No DR": 1.46,
    "Naive Bayes - Low Variance": 1.68,
    "Naive Bayes - High Pearson Correlation": 5.46,
    "Naive Bayes - High Spearman's Rank Correlation": 9.08,
    "Naive Bayes - Low Mutual Info Dependency": 1.16,
    "Naive Bayes - NNG-GS": 1.88,
    "Naive Bayes - MDG-GS": 2.40,
    "Naive Bayes - CDG-GS": 11.14,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageFalsePositivesNames = list(averageFalsePositives.keys())
averageFalsePositivesValues = list(averageFalsePositives.values())

# %% [markdown]
# ### Plot average False Positives

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageFalsePositivesNames, averageFalsePositivesValues, color='orange', width=0.2)
plt.ylabel("Average False Positives", fontsize = 12)
plt.title("Models' average False Positives (confusion matrix)", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 16)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average False Positives in ascending order

# %%
# Sort by values (ascending)
sorted_averageFalsePositives = dict(sorted(averageFalsePositives.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageFalsePositivesNames = list(sorted_averageFalsePositives.keys())
sorted_averageFalsePositivesValues = list(sorted_averageFalsePositives.values())

# %% [markdown]
# ### Plot sorted average False Positives

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageFalsePositivesNames, sorted_averageFalsePositivesValues, color='orange', width=0.2)
plt.ylabel("Average False Positives", fontsize = 12)
plt.title("Models' average False Positives (confusion matrix) - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 16)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <div align="center"><u> Average False Negatives </u>

# %%
# Store the average False Negatives
averageFalseNegatives = {
    "MLP - No DR": 1.64,
    "MLP - Low Variance": 1.74,
    "MLP - High Pearson Correlation": 7.26,
    "MLP - High Spearman's Rank Correlation": 11.34,
    "MLP - Low Mutual Info Dependency": 1.36,
    "MLP - NNG-GS": 2.0,
    "MLP - MDG-GS": 1.80,
    "MLP - CDG-GS": 3.04,
    "kNN - No DR": 0.82,
    "kNN - Low Variance": 1.36,
    "kNN - High Pearson Correlation": 14.72,
    "kNN - High Spearman's Rank Correlation": 14.92,
    "kNN - Low Mutual Info Dependency": 1.52,
    "kNN - NNG-GS": 2.30,
    "kNN - MDG-GS": 3.50,
    "kNN - CDG-GS": 6.34,
    "AdaBoost - No DR": 1.80,
    "AdaBoost - Low Variance": 1.70,
    "AdaBoost - High Pearson Correlation": 8.44,
    "AdaBoost - High Spearman's Rank Correlation": 10.08,
    "AdaBoost - Low Mutual Info Dependency": 1.72,
    "AdaBoost - NNG-GS": 2.08,
    "AdaBoost - MDG-GS": 2.32,
    "AdaBoost - CDG-GS": 6.04,
    "Naive Bayes - No DR": 2.56,
    "Naive Bayes - Low Variance": 1.58,
    "Naive Bayes - High Pearson Correlation": 8.96,
    "Naive Bayes - High Spearman's Rank Correlation": 10.18,
    "Naive Bayes - Low Mutual Info Dependency": 1.84,
    "Naive Bayes - NNG-GS": 1.98,
    "Naive Bayes - MDG-GS": 1.96,
    "Naive Bayes - CDG-GS": 23.28,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageFalseNegativesNames = list(averageFalseNegatives.keys())
averageFalseNegativesValues = list(averageFalseNegatives.values())

# %% [markdown]
# ### Plot average False Negatives

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageFalseNegativesNames, averageFalseNegativesValues, color='blue', width=0.2)
plt.ylabel("Average False Positives", fontsize = 12)
plt.title("Models' average False Positives (confusion matrix)", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 30)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average False Negatives in ascending order

# %%
# Sort by values (ascending)
sorted_averageFalseNegatives = dict(sorted(averageFalseNegatives.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageFalseNegativesNames = list(sorted_averageFalseNegatives.keys())
sorted_averageFalseNegativesValues = list(sorted_averageFalseNegatives.values())

# %% [markdown]
# ### Plot sorted average False Negatives

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageFalseNegativesNames, sorted_averageFalseNegativesValues, color='blue', width=0.2)
plt.ylabel("Average False Negatives", fontsize = 12)
plt.title("Models' average False Negatives (confusion matrix) - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 30)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()
