# %% [markdown]
# # <div align="center"><u>Models' average F1-Score - Plots</u></div>
#
# ## General description of the "Models' average F1-Score - Plots" file
#
# The following analysis includes just plots (for every model):
#
# ### 1. Metrics Overview:
#
# **Evaluation metrics:**
# - Average evaluation F1-Score
# - Average evaluation F1-Score's standard deviation

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ###  Import some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Suppress warnings

# %%
# import warnings

# # To suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # <div align="center"><u> 1. Metrics overview </u>

# %% [markdown]
# ## <div align="center"><u> Evaluation metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average evaluation F1-Score </u>

# %% [markdown]
# ### Store the average evaluation F1-Score

# %%
# Store the average evaluation F1-Score
averageEvaluationF1 = {
     "MLP - No DR": 0.9747,
    "MLP - Low Variance": 0.9747,
    "MLP - High Pearson Correlation": 0.9058,
    "MLP - High Spearman's Rank Correlation": 0.8428,
    "MLP - Low Mutual Info Dependency": 0.9809,
    "MLP - NNG-GS": 0.9683,
    "MLP - MDG-GS": 0.9671,
    "MLP - CDG-GS": 0.9418,
    "kNN - No DR": 0.9795,
    "kNN - Low Variance": 0.9690,
    "kNN - High Pearson Correlation": 0.8539,
    "kNN - High Spearman's Rank Correlation": 0.7995,
    "kNN - Low Mutual Info Dependency": 0.9809,
    "kNN - NNG-GS": 0.9562,
    "kNN - MDG-GS": 0.9619,
    "kNN - CDG-GS": 0.8735,
    "AdaBoost - No DR": 0.9752,
    "AdaBoost - Low Variance": 0.9768,
    "AdaBoost - High Pearson Correlation": 0.8867,
    "AdaBoost - High Spearman's Rank Correlation": 0.8545,
    "AdaBoost - Low Mutual Info Dependency": 0.9759,
    "AdaBoost - NNG-GS": 0.9715,
    "AdaBoost - MDG-GS": 0.9704,
    "AdaBoost - CDG-GS": 0.8916,
    "Naive Bayes - No DR": 0.9707,
    "Naive Bayes - Low Variance": 0.9762,
    "Naive Bayes - High Pearson Correlation": 0.8947,
    "Naive Bayes - High Spearman's Rank Correlation": 0.8593,
    "Naive Bayes - Low Mutual Info Dependency": 0.9781,
    "Naive Bayes - NNG-GS": 0.9718,
    "Naive Bayes - MDG-GS": 0.9682,
    "Naive Bayes - CDG-GS": 0.7473,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationF1Names = list(averageEvaluationF1.keys())
averageEvaluationF1Values = list(averageEvaluationF1.values())

# %% [markdown]
# ### Plot average evaluation F1-Score

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationF1Names, averageEvaluationF1Values, color='black', width=0.2)
plt.ylabel("Average evaluation F1-Score", fontsize = 12)
plt.title("Models' average evaluation F1-Score", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation F1-Score in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationF1 = dict(sorted(averageEvaluationF1.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationF1Names = list(sorted_averageEvaluationF1.keys())
sorted_averageEvaluationF1Values = list(sorted_averageEvaluationF1.values())

# %% [markdown]
# ### Plot sorted average evaluation F1-Score

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationF1Names, sorted_averageEvaluationF1Values, color='black', width=0.2)
plt.ylabel("Average evaluation F1-Score", fontsize = 12)
plt.title("Models' average evaluation F1-Score - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average evaluation F1-Score's standard deviation </u>

# %% [markdown]
# ### Store the average evaluation F1-Score's standard deviation

# %%
# Store the average evaluation F1-Scores's standard deviation
averageEvaluationF1Std = {
    "MLP - No DR": 0.0119,
    "MLP - Low Variance": 0.0118,
    "MLP - High Pearson Correlation": 0.0232,
    "MLP - High Spearman's Rank Correlation": 0.0314,
    "MLP - Low Mutual Info Dependency": 0.0107,
    "MLP - NNG-GS": 0.0138,
    "MLP - MDG-GS": 0.0126,
    "MLP - CDG-GS": 0.0178,
    "kNN - No DR": 0.0109,
    "kNN - Low Variance": 0.0122,
    "kNN - High Pearson Correlation": 0.0235,
    "kNN - High Spearman's Rank Correlation": 0.0278,
    "kNN - Low Mutual Info Dependency": 0.0117,
    "kNN - NNG-GS": 0.0146,
    "kNN - MDG-GS": 0.0149,
    "kNN - CDG-GS": 0.0300,
    "AdaBoost - No DR": 0.0143,
    "AdaBoost - Low Variance": 0.0111,
    "AdaBoost - High Pearson Correlation": 0.0255,
    "AdaBoost - High Spearman's Rank Correlation": 0.0301,
    "AdaBoost - Low Mutual Info Dependency": 0.0122,
    "AdaBoost - NNG-GS": 0.0122,
    "AdaBoost - MDG-GS": 0.0149,
    "AdaBoost - CDG-GS": 0.0262,
    "Naive Bayes - No DR": 0.0148,
    "Naive Bayes - Low Variance": 0.0116,
    "Naive Bayes - High Pearson Correlation": 0.0254,
    "Naive Bayes - High Spearman's Rank Correlation": 0.0278,
    "Naive Bayes - Low Mutual Info Dependency": 0.0126,
    "Naive Bayes - NNG-GS": 0.0125,
    "Naive Bayes - MDG-GS": 0.0130,
    "Naive Bayes - CDG-GS": 0.0489,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationF1StdNames = list(averageEvaluationF1Std.keys())
averageEvaluationF1StdValues = list(averageEvaluationF1Std.values())

# %% [markdown]
# ### Plot average evaluation F1-Score's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationF1StdNames, averageEvaluationF1StdValues, color='silver', width=0.2)
plt.ylabel("Average evaluation F1-Score's standard deviation", fontsize = 12)
plt.title("Models' average evaluation F1-Score's standard deviation", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation F1-Score's standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationF1Std = dict(sorted(averageEvaluationF1Std.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationF1StdNames = list(sorted_averageEvaluationF1Std.keys())
sorted_averageEvaluationF1StdValues = list(sorted_averageEvaluationF1Std.values())

# %% [markdown]
# ### Plot sorted average evaluation F1-Score's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationF1StdNames, sorted_averageEvaluationF1StdValues, color='silver', width=0.2)
plt.ylabel("Average evaluation F1-Score's standard deviation", fontsize = 12)
plt.title("Models' average evaluation F1-Score's standard deviation - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()
