# %% [markdown]
# # <div align="center"><u>Models' average Log Loss - Plots</u></div>
#
# ## General description of the "Models' average Log Loss - Plots" file
#
# The following analysis includes just plots (for every model):
#
# ### 1. Metrics Overview:
#
# **Training metrics:**
# - Average training Log Loss
# - Average training Log Loss' standard deviation
#
# **Evaluation metrics:**
# - Average evaluation Log Loss
# - Average evaluation Log Loss' standard deviation

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ###  Import some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Suppress warnings

# %%
# import warnings

# # To suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # <div align="center"><u> 1. Metrics overview </u>

# %% [markdown]
# ## <div align="center"><u> Training metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average training Log Loss </u>

# %% [markdown]
# ### Store the average training Log Loss

# %%
# Store the average training Log Loss
averageTrainingLogLoss = {
    "MLP - No DR": 0.0010,
    "MLP - Low Variance": 0.0050,
    "MLP - High Pearson Correlation": 0.0073,
    "MLP - High Spearman's Rank Correlation": 0.0085,
    "MLP - Low Mutual Info Dependency": 0.0061,
    "MLP - NNG-GS": 0.0046,
    "MLP - MDG-GS": 0.0049,
    "MLP - CDG-GS": 0.0297,
    "kNN - No DR": 0.0259,
    "kNN - Low Variance": 0.0356,
    "kNN - High Pearson Correlation": 0.1661,
    "kNN - High Spearman's Rank Correlation": 0.2258,
    "kNN - Low Mutual Info Dependency": 0.0179,
    "kNN - NNG-GS": 0.0464,
    "kNN - MDG-GS": 0.0495,
    "kNN - CDG-GS": 0.1353,
    "AdaBoost - No DR": 0.2121,
    "AdaBoost - Low Variance": 0.3230,
    "AdaBoost - High Pearson Correlation": 0.6134,
    "AdaBoost - High Spearman's Rank Correlation": 0.6325,
    "AdaBoost - Low Mutual Info Dependency": 0.1847,
    "AdaBoost - NNG-GS": 0.3859,
    "AdaBoost - MDG-GS": 0.4276,
    "AdaBoost - CDG-GS": 0.6074,
    "Naive Bayes - No DR": 0.9741,
    "Naive Bayes - Low Variance": 0.4382,
    "Naive Bayes - High Pearson Correlation": 0.2950,
    "Naive Bayes - High Spearman's Rank Correlation": 0.3487,
    "Naive Bayes - Low Mutual Info Dependency": 0.6392,
    "Naive Bayes - NNG-GS": 0.5072,
    "Naive Bayes - MDG-GS": 0.6739,
    "Naive Bayes - CDG-GS": 2.5164,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageTrainingLogLossNames = list(averageTrainingLogLoss.keys())
averageTrainingLogLossValues = list(averageTrainingLogLoss.values())

# %% [markdown]
# ### Plot average training Log Loss

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageTrainingLogLossNames, averageTrainingLogLossValues, color='orange', width=0.2)
plt.ylabel("Average training Log Loss", fontsize = 12)
plt.title("Models' average training Log Loss", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 3.0)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average training Log Loss in ascending order

# %%
# Sort by values (ascending)
sorted_averageTrainingLogLoss = dict(sorted(averageTrainingLogLoss.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageTrainingLogLossNames = list(sorted_averageTrainingLogLoss.keys())
sorted_averageTrainingLogLossValues = list(sorted_averageTrainingLogLoss.values())

# %% [markdown]
# ### Plot sorted average training Log Loss

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageTrainingLogLossNames, sorted_averageTrainingLogLossValues, color='orange', width=0.2)
plt.ylabel("Average training Log Loss", fontsize = 12)
plt.title("Models' average training Log Loss - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 3.0)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## <div align="center"><u> Average training Log Loss' standard deviation </u>

# %% [markdown]
# ### Store the average training Log Loss' standard deviation

# %%
# Store the average training Log Loss' standard deviation
averageTrainingLogLossStd = {
    "MLP - No DR": 0.0015,
    "MLP - Low Variance": 0.0013,
    "MLP - High Pearson Correlation": 0.0005,
    "MLP - High Spearman's Rank Correlation": 0.0005,
    "MLP - Low Mutual Info Dependency": 0.0018,
    "MLP - NNG-GS": 0.0010,
    "MLP - MDG-GS": 0.0006,
    "MLP - CDG-GS": 0.0269,
    "kNN - No DR": 0.0043,
    "kNN - Low Variance": 0.0043,
    "kNN - High Pearson Correlation": 0.0117,
    "kNN - High Spearman's Rank Correlation": 0.0140,
    "kNN - Low Mutual Info Dependency": 0.0034,
    "kNN - NNG-GS": 0.0056,
    "kNN - MDG-GS": 0.0061,
    "kNN - CDG-GS": 0.0079,
    "AdaBoost - No DR": 0.0738,
    "AdaBoost - Low Variance": 0.0390,
    "AdaBoost - High Pearson Correlation": 0.0048,
    "AdaBoost - High Spearman's Rank Correlation": 0.0045,
    "AdaBoost - Low Mutual Info Dependency": 0.0812,
    "AdaBoost - NNG-GS": 0.0235,
    "AdaBoost - MDG-GS": 0.0201,
    "AdaBoost - CDG-GS": 0.0040,
    "Naive Bayes - No DR": 0.1493,
    "Naive Bayes - Low Variance": 0.0725,
    "Naive Bayes - High Pearson Correlation": 0.0220,
    "Naive Bayes - High Spearman's Rank Correlation": 0.0341,
    "Naive Bayes - Low Mutual Info Dependency": 0.1224,
    "Naive Bayes - NNG-GS": 0.0788,
    "Naive Bayes - MDG-GS": 0.0858,
    "Naive Bayes - CDG-GS": 0.4350,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageTrainingLogLossStdNames = list(averageTrainingLogLossStd.keys())
averageTrainingLogLossStdValues = list(averageTrainingLogLossStd.values())

# %% [markdown]
# ### Plot average training Log Loss' standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageTrainingLogLossStdNames, averageTrainingLogLossStdValues, color='blue', width=0.2)
plt.ylabel("Average training Log Loss' standard deviation", fontsize = 12)
plt.title("Models' average training Log Loss' standard deviation", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.57)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.03, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average training Log Loss' standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageTrainingLogLossStd = dict(sorted(averageTrainingLogLossStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageTrainingLogLossStdNames = list(sorted_averageTrainingLogLossStd.keys())
sorted_averageTrainingLogLossStdValues = list(sorted_averageTrainingLogLossStd.values())

# %% [markdown]
# ### Plot sorted average training Log Loss' standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageTrainingLogLossStdNames, sorted_averageTrainingLogLossStdValues, color='blue', width=0.2)
plt.ylabel("Average training Log Loss' standard deviation", fontsize = 12)
plt.title("Models' average training Log Loss' standard deviation - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.57)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.03, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <div align="center"><u> Evaluation metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average evaluation Log Loss </u>

# %% [markdown]
# ### Store the average training log loss

# %%
# Store the average evaluation Log Loss
averageEvaluationLogLoss = {
    "MLP - No DR": 0.3351,
    "MLP - Low Variance": 0.0875,
    "MLP - High Pearson Correlation": 0.2571,
    "MLP - High Spearman's Rank Correlation": 0.5200,
    "MLP - Low Mutual Info Dependency": 0.5603,
    "MLP - NNG-GS": 0.1030,
    "MLP - MDG-GS": 0.1293,
    "MLP - CDG-GS": 0.1757,
    "kNN - No DR": 0.2716,
    "kNN - Low Variance": 0.4949,
    "kNN - High Pearson Correlation": 1.1896,
    "kNN - High Spearman's Rank Correlation": 1.8246,
    "kNN - Low Mutual Info Dependency": 0.2580,
    "kNN - NNG-GS": 0.4536,
    "kNN - MDG-GS": 0.5964,
    "kNN - CDG-GS": 1.6473,
    "AdaBoost - No DR": 0.2541,
    "AdaBoost - Low Variance": 0.3405,
    "AdaBoost - High Pearson Correlation": 0.6305,
    "AdaBoost - High Spearman's Rank Correlation": 0.6472,
    "AdaBoost - Low Mutual Info Dependency": 0.2156,
    "AdaBoost - NNG-GS": 0.4037,
    "AdaBoost - MDG-GS": 0.4446,
    "AdaBoost - CDG-GS": 0.6228,
    "Naive Bayes - No DR": 1.0574,
    "Naive Bayes - Low Variance": 0.5205,
    "Naive Bayes - High Pearson Correlation": 0.4120,
    "Naive Bayes - High Spearman's Rank Correlation": 0.5415,
    "Naive Bayes - Low Mutual Info Dependency": 0.7783,
    "Naive Bayes - NNG-GS": 0.6242,
    "Naive Bayes - MDG-GS": 0.7108,
    "Naive Bayes - CDG-GS": 2.5556,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationLogLossNames = list(averageEvaluationLogLoss.keys())
averageEvaluationLogLossValues = list(averageEvaluationLogLoss.values())

# %% [markdown]
# ### Plot average evaluation Log Loss

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationLogLossNames, averageEvaluationLogLossValues, color='orange', width=0.2)
plt.ylabel("Average evaluation Log Loss", fontsize = 12)
plt.title("Models' average evaluation Log Loss", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 3.0)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation Log Loss in ascending orderaccuracy in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationLogLoss = dict(sorted(averageEvaluationLogLoss.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationLogLossNames = list(sorted_averageEvaluationLogLoss.keys())
sorted_averageEvaluationLogLossValues = list(sorted_averageEvaluationLogLoss.values())

# %% [markdown]
# ### Plot average evaluation Log Loss

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationLogLossNames, sorted_averageEvaluationLogLossValues, color='orange', width=0.2)
plt.ylabel("Average evaluation Log Loss", fontsize = 12)
plt.title("Models' average evaluation Log Loss - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 3.0)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average evaluation Log Loss' standard deviation </u>

# %% [markdown]
# ### Store the average evaluation Log Loss' standard deviation

# %%
# Store the average evaluation Log Loss' standard deviation
averageEvaluationLogLossStd = {
    "MLP - No DR": 0.2593,
    "MLP - Low Variance": 0.0440,
    "MLP - High Pearson Correlation": 0.0588,
    "MLP - High Spearman's Rank Correlation": 0.1234,
    "MLP - Low Mutual Info Dependency": 0.0341,
    "MLP - NNG-GS": 0.0502,
    "MLP - MDG-GS": 0.0543,
    "MLP - CDG-GS": 0.0855,
    "kNN - No DR": 0.2290,
    "kNN - Low Variance": 0.2992,
    "kNN - High Pearson Correlation": 0.0233,
    "kNN - High Spearman's Rank Correlation": 0.5984,
    "kNN - Low Mutual Info Dependency": 0.2704,
    "kNN - NNG-GS": 0.3392,
    "kNN - MDG-GS": 0.3815,
    "kNN - CDG-GS": 0.6903,
    "AdaBoost - No DR": 0.0266,
    "AdaBoost - Low Variance": 0.0352,
    "AdaBoost - High Pearson Correlation": 0.0041,
    "AdaBoost - High Spearman's Rank Correlation": 0.0032,
    "AdaBoost - Low Mutual Info Dependency": 0.0631,
    "AdaBoost - NNG-GS": 0.0198,
    "AdaBoost - MDG-GS": 0.0151,
    "AdaBoost - CDG-GS": 0.0045,
    "Naive Bayes - No DR": 0.5356,
    "Naive Bayes - Low Variance": 0.2790,
    "Naive Bayes - High Pearson Correlation": 0.1323,
    "Naive Bayes - High Spearman's Rank Correlation": 0.1397,
    "Naive Bayes - Low Mutual Info Dependency": 0.4501,
    "Naive Bayes - NNG-GS": 0.3414,
    "Naive Bayes - MDG-GS": 0.3721,
    "Naive Bayes - CDG-GS": 0.8633,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationLogLossStdNames = list(averageEvaluationLogLossStd.keys())
averageEvaluationLogLossStdValues = list(averageEvaluationLogLossStd.values())

# %% [markdown]
# ### Plot average evaluation Log Loss' standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationLogLossStdNames, averageEvaluationLogLossStdValues, color='blue', width=0.2)
plt.ylabel("Average evaluation Log Loss' standard deviation", fontsize = 12)
plt.title("Models' average evaluation Log Loss' standard deviation", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.1)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.03, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation Log Loss' standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationLogLossStd = dict(sorted(averageEvaluationLogLossStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationLogLossStdNames = list(sorted_averageEvaluationLogLossStd.keys())
sorted_averageEvaluationLogLossStdValues = list(sorted_averageEvaluationLogLossStd.values())

# %% [markdown]
# ### Plot sorted average evaluation Log Loss' standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationLogLossStdNames, sorted_averageEvaluationLogLossStdValues, color='blue', width=0.2)
plt.ylabel("Average evaluation Log Loss' standard deviation", fontsize = 12)
plt.title("Models' average evaluation Log Loss' standard deviation - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.1)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.03, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()
