# %% [markdown]
# # <div align="center"><u>Models' average accuracy - Plots</u></div>
#
# ## General description of the "Models' average accuracy - Plots" file
#
# The following analysis includes just plots (for every model):
#
# ### 1. Metrics Overview:
#
# **Training metrics:**
# - Average training accuracy
# - Average training accuracy's standard deviation
#
# **Evaluation metrics:**
# - Average evaluation accuracy
# - Average evaluation accuracy's standard deviation

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ###  Import some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Suppress warnings

# %%
# import warnings

# # To suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # <div align="center"><u> 1. Metrics overview </u>

# %% [markdown]
# ## <div align="center"><u> Training metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average training accuracy </u>

# %% [markdown]
# ### Store the average training accuracy

# %%
# Store the average training accuracy
averageTrainingAccuracy = {
    "MLP - No DR": 0.9996,
    "MLP - Low Variance": 1.0000,
    "MLP - High Pearson Correlation": 1.0000,
    "MLP - High Spearman's Rank Correlation": 1.0000,
    "MLP - Low Mutual Info Dependency": 0.9996,
    "MLP - NNG-GS": 1.0000,
    "MLP - MDG-GS": 1.0000,
    "MLP - CDG-GS": 0.9942,
    "kNN - No DR": 0.9871,
    "kNN - Low Variance": 0.9821,
    "kNN - High Pearson Correlation": 0.9427,
    "kNN - High Spearman's Rank Correlation": 0.9117,
    "kNN - Low Mutual Info Dependency": 0.9897,
    "kNN - NNG-GS": 0.9798,
    "kNN - MDG-GS": 0.9774,
    "kNN - CDG-GS": 0.9362,
    "AdaBoost - No DR": 1.0000,
    "AdaBoost - Low Variance": 1.0000,
    "AdaBoost - High Pearson Correlation": 0.9804,
    "AdaBoost - High Spearman's Rank Correlation": 0.9747,
    "AdaBoost - Low Mutual Info Dependency": 1.0000,
    "AdaBoost - NNG-GS": 1.0000,
    "AdaBoost - MDG-GS": 1.0000,
    "AdaBoost - CDG-GS": 0.9718,
    "Naive Bayes - No DR": 0.9729,
    "Naive Bayes - Low Variance": 0.9778,
    "Naive Bayes - High Pearson Correlation": 0.9165,
    "Naive Bayes - High Spearman's Rank Correlation": 0.8989,
    "Naive Bayes - Low Mutual Info Dependency": 0.9816,
    "Naive Bayes - NNG-GS": 0.9755,
    "Naive Bayes - MDG-GS": 0.9686,
    "Naive Bayes - CDG-GS": 0.7501,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageTrainingAccuracyNames = list(averageTrainingAccuracy.keys())
averageTrainingAccuracyValues = list(averageTrainingAccuracy.values())

# %% [markdown]
# ### Plot average training accuracy

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageTrainingAccuracyNames, averageTrainingAccuracyValues, color='green', width=0.2)
plt.ylabel("Average training accuracy", fontsize = 12)
plt.title("Models' average training accuracy", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average training accuracy in ascending order

# %%
# Sort by values (ascending)
sorted_averageTrainingAccuracy = dict(sorted(averageTrainingAccuracy.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageTrainingAccuracyNames = list(sorted_averageTrainingAccuracy.keys())
sorted_averageTrainingAccuracyValues = list(sorted_averageTrainingAccuracy.values())

# %% [markdown]
# ### Plot sorted average training accuracy

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageTrainingAccuracyNames, sorted_averageTrainingAccuracyValues, color='green', width=0.2)
plt.ylabel("Average training accuracy", fontsize = 12)
plt.title("Models' average training accuracy - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average training accuracy's standard deviation </u>

# %% [markdown]
# ### Store the average training accuracy's standard deviation

# %%
# Store the average training accuracy's standard deviation
averageTrainingAccuracyStd = {
    "MLP - No DR": 0.0012,
    "MLP - Low Variance": 0.0000,
    "MLP - High Pearson Correlation": 0.0000,
    "MLP - High Spearman's Rank Correlation": 0.0000,
    "MLP - Low Mutual Info Dependency": 0.0009,
    "MLP - NNG-GS": 0.0000,
    "MLP - MDG-GS": 0.0000,
    "MLP - CDG-GS": 0.0086,
    "kNN - No DR": 0.0035,
    "kNN - Low Variance": 0.0039,
    "kNN - High Pearson Correlation": 0.0110,
    "kNN - High Spearman's Rank Correlation": 0.0125,
    "kNN - Low Mutual Info Dependency": 0.0029,
    "kNN - NNG-GS": 0.0042,
    "kNN - MDG-GS": 0.0050,
    "kNN - CDG-GS": 0.0065,
    "AdaBoost - No DR": 0.0000,
    "AdaBoost - Low Variance": 0.0000,
    "AdaBoost - High Pearson Correlation": 0.0048,
    "AdaBoost - High Spearman's Rank Correlation": 0.0070,
    "AdaBoost - Low Mutual Info Dependency": 0.0000,
    "AdaBoost - NNG-GS": 0.0000,
    "AdaBoost - MDG-GS": 0.0000,
    "AdaBoost - CDG-GS": 0.0065,
    "Naive Bayes - No DR": 0.0042,
    "Naive Bayes - Low Variance": 0.0044,
    "Naive Bayes - High Pearson Correlation": 0.0071,
    "Naive Bayes - High Spearman's Rank Correlation": 0.0092,
    "Naive Bayes - Low Mutual Info Dependency": 0.0034,
    "Naive Bayes - NNG-GS": 0.0043,
    "Naive Bayes - MDG-GS": 0.0044,
    "Naive Bayes - CDG-GS": 0.0223,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageTrainingAccuracyStdNames = list(averageTrainingAccuracyStd.keys())
averageTrainingAccuracyStdValues = list(averageTrainingAccuracyStd.values())

# %% [markdown]
# ### Plot average training accuracy's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageTrainingAccuracyStdNames, averageTrainingAccuracyStdValues, color='red', width=0.2)
plt.ylabel("Average training accuracy's standard deviation", fontsize = 12)
plt.title("Models' average training accuracy's standard deviation", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.028)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.0005, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average training accuracy's standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageTrainingAccuracyStd = dict(sorted(averageTrainingAccuracyStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageTrainingAccuracyStdNames = list(sorted_averageTrainingAccuracyStd.keys())
sorted_averageTrainingAccuracyStdValues = list(sorted_averageTrainingAccuracyStd.values())

# %% [markdown]
# ### Plot sorted average training accuracy's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageTrainingAccuracyStdNames, sorted_averageTrainingAccuracyStdValues, color='red', width=0.2)
plt.ylabel("Average training accuracy's standard deviation", fontsize = 12)
plt.title("Models' average training accuracy's standard deviation - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.028)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.0005, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## <div align="center"><u> Evaluation metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average evaluation accuracy </u>

# %% [markdown]
# ### Store the average evaluation accuracy

# %%
# Store the average evaluation accuracy
averageEvaluationAccuracy = {
    "MLP - No DR": 0.9747,
    "MLP - Low Variance": 0.9747,
    "MLP - High Pearson Correlation": 0.9058,
    "MLP - High Spearman's Rank Correlation": 0.8492,
    "MLP - Low Mutual Info Dependency": 0.9809,
    "MLP - NNG-GS": 0.9683,
    "MLP - MDG-GS": 0.9672,
    "MLP - CDG-GS": 0.9419,
    "kNN - No DR": 0.9796,
    "kNN - Low Variance": 0.9621,
    "kNN - High Pearson Correlation": 0.8543,
    "kNN - High Spearman's Rank Correlation": 0.7997,
    "kNN - Low Mutual Info Dependency": 0.9809,
    "kNN - NNG-GS": 0.9562,
    "kNN - MDG-GS": 0.9619,
    "kNN - CDG-GS": 0.8740,
    "AdaBoost - No DR": 0.9752,
    "AdaBoost - Low Variance": 0.9768,
    "AdaBoost - High Pearson Correlation": 0.8867,
    "AdaBoost - High Spearman's Rank Correlation": 0.8546,
    "AdaBoost - Low Mutual Info Dependency": 0.9759,
    "AdaBoost - NNG-GS": 0.9715,
    "AdaBoost - MDG-GS": 0.9704,
    "AdaBoost - CDG-GS": 0.8918,
    "Naive Bayes - No DR": 0.9707,
    "Naive Bayes - Low Variance": 0.9762,
    "Naive Bayes - High Pearson Correlation": 0.8947,
    "Naive Bayes - High Spearman's Rank Correlation": 0.8594,
    "Naive Bayes - Low Mutual Info Dependency": 0.9781,
    "Naive Bayes - NNG-GS": 0.9718,
    "Naive Bayes - MDG-GS": 0.9682,
    "Naive Bayes - CDG-GS": 0.7488,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationAccuracyNames = list(averageEvaluationAccuracy.keys())
averageEvaluationAccuracyValues = list(averageEvaluationAccuracy.values())

# %% [markdown]
# ### Plot average evaluation accuracy

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationAccuracyNames, averageEvaluationAccuracyValues, color='green', width=0.2)
plt.ylabel("Average evaluation accuracy", fontsize = 12)
plt.title("Models' average evaluation accuracy", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation accuracy in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationAccuracy = dict(sorted(averageEvaluationAccuracy.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationAccuracyNames = list(sorted_averageEvaluationAccuracy.keys())
sorted_averageEvaluationAccuracyValues = list(sorted_averageEvaluationAccuracy.values())

# %% [markdown]
# ### Plot sorted average evaluation accuracy

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationAccuracyNames, sorted_averageEvaluationAccuracyValues, color='green', width=0.2)
plt.ylabel("Average evaluation accuracy", fontsize = 12)
plt.title("Models' average evaluation accuracy - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average evaluation accuracy's standard deviation </u>

# %% [markdown]
# ### Store the average evaluation accuracy's standard deviation

# %%
# Store the average evaluation accuracy's standard deviation
averageEvaluationAccuracyStd = {
    "MLP - No DR": 0.0119,
    "MLP - Low Variance": 0.0118,
    "MLP - High Pearson Correlation": 0.0232,
    "MLP - High Spearman's Rank Correlation": 0.0314,
    "MLP - Low Mutual Info Dependency": 0.0107,
    "MLP - NNG-GS": 0.0138,
    "MLP - MDG-GS": 0.0126,
    "MLP - CDG-GS": 0.0176,
    "kNN - No DR": 0.0109,
    "kNN - Low Variance": 0.0122,
    "kNN - High Pearson Correlation": 0.0233,
    "kNN - High Spearman's Rank Correlation": 0.0277,
    "kNN - Low Mutual Info Dependency": 0.0117,
    "kNN - NNG-GS": 0.0145,
    "kNN - MDG-GS": 0.0149,
    "kNN - CDG-GS": 0.0297,
    "AdaBoost - No DR": 0.0143,
    "AdaBoost - Low Variance": 0.0111,
    "AdaBoost - High Pearson Correlation": 0.0255,
    "AdaBoost - High Spearman's Rank Correlation": 0.0301,
    "AdaBoost - Low Mutual Info Dependency": 0.0122,
    "AdaBoost - NNG-GS": 0.0121,
    "AdaBoost - MDG-GS": 0.0149,
    "AdaBoost - CDG-GS": 0.0261,
    "Naive Bayes - No DR": 0.0149,
    "Naive Bayes - Low Variance": 0.0116,
    "Naive Bayes - High Pearson Correlation": 0.0254,
    "Naive Bayes - High Spearman's Rank Correlation": 0.0277,
    "Naive Bayes - Low Mutual Info Dependency": 0.0126,
    "Naive Bayes - NNG-GS": 0.0125,
    "Naive Bayes - MDG-GS": 0.0130,
    "Naive Bayes - CDG-GS": 0.0478,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationAccuracyStdNames = list(averageEvaluationAccuracyStd.keys())
averageEvaluationAccuracyStdValues = list(averageEvaluationAccuracyStd.values())

# %% [markdown]
# ### Plot average evaluation accuracy's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationAccuracyStdNames, averageEvaluationAccuracyStdValues, color='red', width=0.2)
plt.ylabel("Average evaluation accuracy's standard deviation", fontsize = 12)
plt.title("Models' average evaluation accuracy's standard deviation", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation accuracy's standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationAccuracyStd = dict(sorted(averageEvaluationAccuracyStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationAccuracyStdNames = list(sorted_averageEvaluationAccuracyStd.keys())
sorted_averageEvaluationAccuracyStdValues = list(sorted_averageEvaluationAccuracyStd.values())

# %% [markdown]
# ### Plot sorted average evaluation accuracy's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationAccuracyStdNames, sorted_averageEvaluationAccuracyStdValues, color='red', width=0.2)
plt.ylabel("Average evaluation accuracy's standard deviation", fontsize = 12)
plt.title("Models' average evaluation accuracy's standard deviation - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()
