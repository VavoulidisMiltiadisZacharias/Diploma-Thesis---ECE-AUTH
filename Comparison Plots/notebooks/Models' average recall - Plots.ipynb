# %% [markdown]
# # <div align="center"><u>Models' average recall - Plots</u></div>
#
# ## General description of the "Models' average recall - Plots" file
#
# The following analysis includes just plots (for every model):
#
# ### 1. Metrics Overview:
#
# **Evaluation metrics:**
# - Average evaluation recall
# - Average evaluation recall's standard deviation

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ###  Import some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Suppress warnings

# %%
# import warnings

# # To suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # <div align="center"><u> 1. Metrics overview </u>

# %% [markdown]
# ## <div align="center"><u> Evaluation metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average evaluation recall </u>

# %% [markdown]
# ### Store the average evaluation recall

# %%
# Store the average evaluation recall
averageEvaluationRecall = {
    "MLP - No DR": 0.9747,
    "MLP - Low Variance": 0.9747,
    "MLP - High Pearson Correlation": 0.9058,
    "MLP - High Spearman's Rank Correlation": 0.8429,
    "MLP - Low Mutual Info Dependency": 0.9809,
    "MLP - NNG-GS": 0.9683,
    "MLP - MDG-GS": 0.9672,
    "MLP - CDG-GS": 0.9419,
    "kNN - No DR": 0.9796,
    "kNN - Low Variance": 0.9691,
    "kNN - High Pearson Correlation": 0.8543,
    "kNN - High Spearman's Rank Correlation": 0.7997,
    "kNN - Low Mutual Info Dependency": 0.9809,
    "kNN - NNG-GS": 0.9562,
    "kNN - MDG-GS": 0.9619,
    "kNN - CDG-GS": 0.8740,
    "AdaBoost - No DR": 0.9752,
    "AdaBoost - Low Variance": 0.9768,
    "AdaBoost - High Pearson Correlation": 0.8867,
    "AdaBoost - High Spearman's Rank Correlation": 0.8546,
    "AdaBoost - Low Mutual Info Dependency": 0.9759,
    "AdaBoost - NNG-GS": 0.9715,
    "AdaBoost - MDG-GS": 0.9704,
    "AdaBoost - CDG-GS": 0.8918,
    "Naive Bayes - No DR": 0.9707,
    "Naive Bayes - Low Variance": 0.9762,
    "Naive Bayes - High Pearson Correlation": 0.8947,
    "Naive Bayes - High Spearman's Rank Correlation": 0.8594,
    "Naive Bayes - Low Mutual Info Dependency": 0.9781,
    "Naive Bayes - NNG-GS": 0.9718,
    "Naive Bayes - MDG-GS": 0.9682,
    "Naive Bayes - CDG-GS": 0.7488,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationRecallNames = list(averageEvaluationRecall.keys())
averageEvaluationRecallValues = list(averageEvaluationRecall.values())

# %% [markdown]
# ### Plot average evaluation recall

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationRecallNames, averageEvaluationRecallValues, color='lime', width=0.2)
plt.ylabel("Average evaluation recall", fontsize = 12)
plt.title("Models' average evaluation recall", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation precision in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationRecall = dict(sorted(averageEvaluationRecall.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationRecallNames = list(sorted_averageEvaluationRecall.keys())
sorted_averageEvaluationRecallValues = list(sorted_averageEvaluationRecall.values())

# %% [markdown]
# ### Plot sorted average evaluation recall

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationRecallNames, sorted_averageEvaluationRecallValues, color='lime', width=0.2)
plt.ylabel("Average evaluation recall", fontsize = 12)
plt.title("Models' average evaluation recall - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average evaluation recall's standard deviation </u>

# %% [markdown]
# ### Store the average evaluation recall's standard deviation

# %%
# Store the average evaluation recall's standard deviation
averageEvaluationRecallStd = {
    "MLP - No DR": 0.0119,
    "MLP - Low Variance": 0.0118,
    "MLP - High Pearson Correlation": 0.0232,
    "MLP - High Spearman's Rank Correlation": 0.0314,
    "MLP - Low Mutual Info Dependency": 0.0107,
    "MLP - NNG-GS": 0.0138,
    "MLP - MDG-GS": 0.0126,
    "MLP - CDG-GS": 0.0176,
    "kNN - No DR": 0.0109,
    "kNN - Low Variance": 0.0122,
    "kNN - High Pearson Correlation": 0.0233,
    "kNN - High Spearman's Rank Correlation": 0.0277,
    "kNN - Low Mutual Info Dependency": 0.0117,
    "kNN - NNG-GS": 0.0145,
    "kNN - MDG-GS": 0.0149,
    "kNN - CDG-GS": 0.0297,
    "AdaBoost - No DR": 0.0143,
    "AdaBoost - Low Variance": 0.0111,
    "AdaBoost - High Pearson Correlation": 0.0255,
    "AdaBoost - High Spearman's Rank Correlation": 0.0301,
    "AdaBoost - Low Mutual Info Dependency": 0.0122,
    "AdaBoost - NNG-GS": 0.0121,
    "AdaBoost - MDG-GS": 0.0149,
    "AdaBoost - CDG-GS": 0.0261,
    "Naive Bayes - No DR": 0.0149,
    "Naive Bayes - Low Variance": 0.0116,
    "Naive Bayes - High Pearson Correlation": 0.0254,
    "Naive Bayes - High Spearman's Rank Correlation": 0.0277,
    "Naive Bayes - Low Mutual Info Dependency": 0.0126,
    "Naive Bayes - NNG-GS": 0.0125,
    "Naive Bayes - MDG-GS": 0.0130,
    "Naive Bayes - CDG-GS": 0.0478,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationRecallStdNames = list(averageEvaluationRecallStd.keys())
averageEvaluationRecallStdValues = list(averageEvaluationRecallStd.values())

# %% [markdown]
# ### Plot average evaluation recall's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationRecallStdNames, averageEvaluationRecallStdValues, color='aquamarine', width=0.2)
plt.ylabel("Average evaluation recall's standard deviation", fontsize = 12)
plt.title("Models' average evaluation recall's standard deviation", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation recall's standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationRecallStd = dict(sorted(averageEvaluationRecallStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationRecallStdNames = list(sorted_averageEvaluationRecallStd.keys())
sorted_averageEvaluationRecallStdValues = list(sorted_averageEvaluationRecallStd.values())

# %% [markdown]
# ### Plot sorted average evaluation recall's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationRecallStdNames, sorted_averageEvaluationRecallStdValues, color='aquamarine', width=0.2)
plt.ylabel("Average evaluation recall's standard deviation", fontsize = 12)
plt.title("Models' average evaluation recall's standard deviation - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()
