# %% [markdown]
# # <div align="center"><u>Models' average AUC-ROC - Plots</u></div>
#
# ## General description of the "Models' average AUC-ROC - Plots" file
#
# The following analysis includes just plots (for every model):
#
# ### 1. Metrics Overview:
#
# **Evaluation metrics:**
# - Average evaluation AUC-ROC
# - Average evaluation AUC-ROC's standard deviation

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ###  Import some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Suppress warnings

# %%
# import warnings

# # To suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # <div align="center"><u> 1. Metrics overview </u>

# %% [markdown]
# ## <div align="center"><u> Evaluation metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average evaluation AUC-ROC </u>

# %% [markdown]
# ### Store the average evaluation AUC-ROC

# %%
# Store the average evaluation AUC-ROC
averageEvaluationAUCROC = {
    "MLP - No DR": 0.9957,
    "MLP - Low Variance": 0.9963,
    "MLP - High Pearson Correlation": 0.9058,
    "MLP - High Spearman's Rank Correlation": 0.9103,
    "MLP - Low Mutual Info Dependency": 0.9984,
    "MLP - NNG-GS": 0.9946,
    "MLP - MDG-GS": 0.9889,
    "MLP - CDG-GS": 0.9849,
    "kNN - No DR": 0.9922,
    "kNN - Low Variance": 0.9854,
    "kNN - High Pearson Correlation": 0.9256,
    "kNN - High Spearman's Rank Correlation": 0.8608,
    "kNN - Low Mutual Info Dependency": 0.9930,
    "kNN - NNG-GS": 0.9851,
    "kNN - MDG-GS": 0.9818,
    "kNN - CDG-GS": 0.9258,
    "AdaBoost - No DR": 0.9979,
    "AdaBoost - Low Variance": 0.9975,
    "AdaBoost - High Pearson Correlation": 0.9481,
    "AdaBoost - High Spearman's Rank Correlation": 0.9273,
    "AdaBoost - Low Mutual Info Dependency": 0.9976,
    "AdaBoost - NNG-GS": 0.9952,
    "AdaBoost - MDG-GS": 0.9951,
    "AdaBoost - CDG-GS": 0.9553,
    "Naive Bayes - No DR": 0.9719,
    "Naive Bayes - Low Variance": 0.9923,
    "Naive Bayes - High Pearson Correlation": 0.9564,
    "Naive Bayes - High Spearman's Rank Correlation": 0.9332,
    "Naive Bayes - Low Mutual Info Dependency": 0.9878,
    "Naive Bayes - NNG-GS": 0.9911,
    "Naive Bayes - MDG-GS": 0.9844,
    "Naive Bayes - CDG-GS": 0.8688,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationAUCROCNames = list(averageEvaluationAUCROC.keys())
averageEvaluationAUCROCValues = list(averageEvaluationAUCROC.values())

# %% [markdown]
# ### Plot average evaluation AUC-ROC

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationAUCROCNames, averageEvaluationAUCROCValues, color='sienna', width=0.2)
plt.ylabel("Average evaluation AUC-ROC", fontsize = 12)
plt.title("Models' average evaluation AUC-ROC", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation AUC-ROC in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationAUCROC = dict(sorted(averageEvaluationAUCROC.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationAUCROCNames = list(sorted_averageEvaluationAUCROC.keys())
sorted_averageEvaluationAUCROCValues = list(sorted_averageEvaluationAUCROC.values())

# %% [markdown]
# ### Plot sorted average evaluation AUC-ROC

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationAUCROCNames, sorted_averageEvaluationAUCROCValues, color='sienna', width=0.2)
plt.ylabel("Average evaluation AUC-ROC", fontsize = 12)
plt.title("Models' average evaluation AUC-ROC - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average evaluation AUC-ROC's standard deviation </u>

# %% [markdown]
# ### Store the average evaluation AUC-ROC's standard deviation

# %%
# Store the average evaluation AUC-ROC's standard deviation
averageEvaluationAUCROCStd = {
     "MLP - No DR": 0.0045,
    "MLP - Low Variance": 0.0034,
    "MLP - High Pearson Correlation": 0.0118,
    "MLP - High Spearman's Rank Correlation": 0.0242,
    "MLP - Low Mutual Info Dependency": 0.0017,
    "MLP - NNG-GS": 0.0045,
    "MLP - MDG-GS": 0.0070,
    "MLP - CDG-GS": 0.0101,
    "kNN - No DR": 0.0069,
    "kNN - Low Variance": 0.0088,
    "kNN - High Pearson Correlation": 0.0172,
    "kNN - High Spearman's Rank Correlation": 0.0252,
    "kNN - Low Mutual Info Dependency": 0.0076,
    "kNN - NNG-GS": 0.0101,
    "kNN - MDG-GS": 0.0112,
    "kNN - CDG-GS": 0.0251,
    "AdaBoost - No DR": 0.0026,
    "AdaBoost - Low Variance": 0.0024,
    "AdaBoost - High Pearson Correlation": 0.0175,
    "AdaBoost - High Spearman's Rank Correlation": 0.0218,
    "AdaBoost - Low Mutual Info Dependency": 0.0024,
    "AdaBoost - NNG-GS": 0.0032,
    "AdaBoost - MDG-GS": 0.0380,
    "AdaBoost - CDG-GS": 0.0160,
    "Naive Bayes - No DR": 0.0139,
    "Naive Bayes - Low Variance": 0.0069,
    "Naive Bayes - High Pearson Correlation": 0.0167,
    "Naive Bayes - High Spearman's Rank Correlation": 0.0189,
    "Naive Bayes - Low Mutual Info Dependency": 0.0092,
    "Naive Bayes - NNG-GS": 0.0068,
    "Naive Bayes - MDG-GS": 0.0108,
    "Naive Bayes - CDG-GS": 0.0389,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationAUCROCStdNames = list(averageEvaluationAUCROCStd.keys())
averageEvaluationAUCROCStdValues = list(averageEvaluationAUCROCStd.values())

# %% [markdown]
# ### Plot average evaluation AUC-ROC's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(averageEvaluationAUCROCStdNames, averageEvaluationAUCROCStdValues, color='deeppink', width=0.2)
plt.ylabel("Average evaluation AUC-ROC's standard deviation", fontsize = 12)
plt.title("Models' average evaluation AUC-ROC's standard deviation", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation AUC-ROC's standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationAUCROCStd = dict(sorted(averageEvaluationAUCROCStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationAUCROCStdNames = list(sorted_averageEvaluationAUCROCStd.keys())
sorted_averageEvaluationAUCROCStdValues = list(sorted_averageEvaluationAUCROCStd.values())

# %% [markdown]
# ### Plot sorted average evaluation AUC-ROC's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(12, 10))
bars = plt.bar(sorted_averageEvaluationAUCROCStdNames, sorted_averageEvaluationAUCROCStdValues, color='deeppink', width=0.2)
plt.ylabel("Average evaluation AUC-ROC's standard deviation", fontsize = 12)
plt.title("Models' average evaluation AUC-ROC's standard deviation - Sorted", fontsize = 16)
plt.xticks(rotation=90, ha='right', fontsize = 12)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=12, rotation=90)

plt.tight_layout()
plt.show()
